# %%
import pandas as pd

# %%
#將資料集載入
data = pd.read_excel("sales.xlsx")

# %%
#1.使用 pandas 將資料集載入為 DataFrame 格式

sales = pd.DataFrame(data)

# %%
#2. 列出目前資料集所有欄位名稱及資料型態。
sales.dtypes
# Out:
# Year           int64
# Product       object
# line          object
# Product.1     object
# type          object
# Product.2     object
# Order         object
# method        object
# type.1        object
# Retailer      object
# country       object
# Revenue       object
# Planned       object
# revenue       object
# Product.3     object
# cost         float64
# Quantity     float64
# Unit         float64
# cost.1       float64
# Unit.1       float64
# price        float64
# Gross        float64
# profit       float64
# Unit.2       float64
# sale         float64
# price.1      float64
# dtype: object

# %%
#3. 依已知資訊(1)，列出所有正確的欄位名稱
salescol=sales
print(salescol.columns[0]) 
print(salescol.columns[1]+' '+sales.columns[2])
print(salescol.columns[3][0:7]+' '+sales.columns[4])
print(salescol.columns[5][0:7])
print(salescol.columns[6]+' '+sales.columns[7]+' '+sales.columns[8][0:4])
print(salescol.columns[9]+' '+sales.columns[10])
print(salescol.columns[11])
print(salescol.columns[12]+' '+sales.columns[13])
print(salescol.columns[14][0:7]+' '+sales.columns[15])
print(salescol.columns[16])
print(salescol.columns[17]+' '+sales.columns[18][0:4])
print(salescol.columns[19][0:4]+' '+sales.columns[20])
print(salescol.columns[21]+' '+sales.columns[22])
print(salescol.columns[23][0:4]+' '+sales.columns[24]+' '+sales.columns[25][0:5])
# Out:
# Year
# Product line
# Product type
# Product
# Order method type
# Retailer country
# Revenue
# Planned revenue
# Product cost
# Quantity
# Unit cost
# Unit price
# Gross profit
# Unit sale price

# %%
#4. 檢查第 1 個欄位 Year 是否有資料錯置問題。
sales.groupby(['Year']).size()
# Out:
# Year
# 2004    21168
# 2005    21168
# 2006    21168
# 2007     2031
# dtype: int64

# %%
#4. 檢查第 1 個欄位 Year 是否有資料錯置問題。

sales.groupby(['Year','Product']).size()
# Out:
# Year  Product
# 2004  Camping           6027
#       Golf              2205
#       Mountaineering    3087
#       Outdoor           2205
#       Personal          7644
# 2005  Camping           6027
#       Golf              2205
#       Mountaineering    3087
#       Outdoor           2205
#       Personal          7644
# 2006  Camping           6027
#       Golf              2205
#       Mountaineering    3087
#       Outdoor           2205
#       Personal          7644
# 2007  Camping           2031
# dtype: int64

# %%
#5. 檢查第 2 個欄位 Product line 的資料錯置情況
sales.groupby(['Product','line']).size()
# Out:
# Product         line
# Camping         Equipment      20112
# Golf            Equipment       6615
# Mountaineering  Equipment       9261
# Outdoor         Protection      6615
# Personal        Accessories    22932
# dtype: int64

# %%
#5. 檢查第 2 個欄位 Product line 的資料錯置情況

sales.groupby(['Product','line','Product.1']).size()
# Out:
# Product         line         Product.1
# Camping         Equipment    Cooking       5880
#                              Lanterns      5292
#                              Packs         2646
#                              Sleeping      3087
#                              Tents         3207
# Golf            Equipment    Golf          1764
#                              Irons         1764
#                              Putters       1323
#                              Woods         1764
# Mountaineering  Equipment    Climbing      3087
#                              Rope          1764
#                              Safety        1764
#                              Tools         2646
# Outdoor         Protection   First         2205
#                              Insect        2205
#                              Sunscreen     2205
# Personal        Accessories  Binoculars    2646
#                              Eyewear       7056
#                              Knives        3087
# ...

# %%
#5.將「Product」及「line」欄位合併，並將合併後的值指定給新增的欄位 Product line 
#使用 drop()移除不需要的欄位

sales['Product line'] = sales['Product']+' '+sales['line']
sales = sales.drop(['Product','line'],axis=1)
sales.head()
# Out:
#    Year Product.1  type  Product.2  Order method     type.1 Retailer  country  \
# 0  2004   Cooking  Gear  TrailChef  Water    Bag  Telephone   United   States
# 1  2004   Cooking  Gear  TrailChef  Water    Bag  Telephone   Canada  13444.7
# 2  2004   Cooking  Gear  TrailChef  Water    Bag  Telephone   Mexico      NaN
# 3  2004   Cooking  Gear  TrailChef  Water    Bag  Telephone   Brazil      NaN
# 4  2004   Cooking  Gear  TrailChef  Water    Bag  Telephone    Japan   181120
#
#    Revenue  ...        Unit    cost.1 Unit.1  price  Gross  profit  Unit.2  \
# 0   315044  ...  156672.570  5.195714    NaN    NaN    NaN     NaN     NaN
# 1  14313.5  ...       6.190       NaN    NaN    NaN    NaN     NaN     NaN
# 2      NaN  ...         NaN       NaN    NaN    NaN    NaN     NaN     NaN
# 3      NaN  ...         NaN       NaN    NaN    NaN    NaN     NaN     NaN
# 4   235237  ...       5.488       NaN    NaN    NaN    NaN     NaN     NaN
#
#    sale  price.1       Product line
# ...

# %%
#6. 依已知資訊(3)過濾掉不相干的 Product type 的銷售紀錄 
sales['Product.1 type'] = sales['Product.1']+' '+sales['type']

condition = (sales["Product.1 type"] =='Cooking Gear') \
            | (sales["Product.1 type"] =='Climbing Accessories') \
            | (sales["Product.1 type"] =='First Aid') \
            | (sales["Product.1 type"] =='Golf Accessories') \
            | (sales["Product.1 type"] =='Insect Repellents') \
            | (sales["Product.1 type"] =='Sleeping Bags') \

sales1 = sales[condition]
sales1 = sales1.drop(['Product.1 type'],axis=1)
sales1
# Out:
#        Year Product.1  type  Product.2     Order  method       type.1  \
# 0      2004   Cooking  Gear  TrailChef     Water     Bag    Telephone
# 1      2004   Cooking  Gear  TrailChef     Water     Bag    Telephone
# 2      2004   Cooking  Gear  TrailChef     Water     Bag    Telephone
# 3      2004   Cooking  Gear  TrailChef     Water     Bag    Telephone
# 4      2004   Cooking  Gear  TrailChef     Water     Bag    Telephone
# 5      2004   Cooking  Gear  TrailChef     Water     Bag    Telephone
# 6      2004   Cooking  Gear  TrailChef     Water     Bag    Telephone
# 7      2004   Cooking  Gear  TrailChef     Water     Bag    Telephone
# 8      2004   Cooking  Gear  TrailChef     Water     Bag    Telephone
# 9      2004   Cooking  Gear  TrailChef     Water     Bag    Telephone
# 10     2004   Cooking  Gear  TrailChef     Water     Bag    Telephone
# 11     2004   Cooking  Gear  TrailChef     Water     Bag    Telephone
# ...

# %%
#7. 檢查第 3 個欄位 Product type 的資料錯置情況
sales1.groupby(['Product.1', 'type','Product.2']).size()
# Out:
# Product.1  type         Product.2
# Climbing   Accessories  Firefly       1323
#                         Granite       1764
# Cooking    Gear         TrailChef     5880
# First      Aid          Aloe           441
#                         Calamine       441
#                         Compact        441
#                         Deluxe         441
#                         Insect         441
# Golf       Accessories  Course        1764
# Insect     Repellents   BugShield     2205
# Sleeping   Bags         Hibernator    3087
# dtype: int64

# %%
#7.將第3個欄位Product type整理成正確的形式
sales1['Product.1 type'] = sales1['Product.1']+' '+sales1['type']
sales1 = sales1.drop(['Product.1','type'],axis=1)
sales1
# Out:
#        Year  Product.2     Order  method       type.1     Retailer    country  \
# 0      2004  TrailChef     Water     Bag    Telephone       United     States
# 1      2004  TrailChef     Water     Bag    Telephone       Canada    13444.7
# 2      2004  TrailChef     Water     Bag    Telephone       Mexico        NaN
# 3      2004  TrailChef     Water     Bag    Telephone       Brazil        NaN
# 4      2004  TrailChef     Water     Bag    Telephone        Japan     181120
# 5      2004  TrailChef     Water     Bag    Telephone        Korea        NaN
# 6      2004  TrailChef     Water     Bag    Telephone        China    69608.1
# 7      2004  TrailChef     Water     Bag    Telephone    Singapore    30940.3
# 8      2004  TrailChef     Water     Bag    Telephone    Australia        NaN
# 9      2004  TrailChef     Water     Bag    Telephone  Netherlands    74321.2
# 10     2004  TrailChef     Water     Bag    Telephone       Sweden    18474.2
# ...

# %%
#8. 檢查第 4 個欄位 Product 的資料錯置情況
sales1.groupby(['Product.2','Order']).size()
# Out:
# Product.2   Order
# Aloe        Relief           441
# BugShield   Extreme          441
#             Lotion           882
#             Natural          441
#             Spray            441
# Calamine    Relief           441
# Compact     Relief           441
# Course      Pro             1764
# Deluxe      Family           441
# Firefly     Charger          441
#             Climbing         441
#             Rechargeable     441
# Granite     Belay            441
#             Carabiner        441
#             Chalk            441
#             Pulley           441
# Hibernator  Camp             441
#             E-mail            63
#             Extreme          441
#             Fax               63
#             Lite             441
#             Mail              63
#             Pad              441
#             Pillow           441
#             Sales             63
#             Self             441
#             Special           63
#             Telephone         63
# ...

# %%
#8. 檢查第 4 個欄位 Product 的資料錯置情況
sales1.groupby(['Product.2','Order','method']).size()
# Out:
# Product.2  Order     method
# Aloe       Relief    E-mail        63
#                      Fax           63
#                      Mail          63
#                      Sales         63
#                      Special       63
#                      Telephone     63
#                      Web           63
# BugShield  Extreme   E-mail        63
#                      Fax           63
#                      Mail          63
#                      Sales         63
#                      Special       63
#                      Telephone     63
#                      Web           63
#            Lotion    E-mail        63
#                      Fax           63
#                      Lite         441
#                      Mail          63
#                      Sales         63
#                      Special       63
#                      Telephone     63
#                      Web           63
#            Natural   E-mail        63
#                      Fax           63
# ...

# %%
#9. 請檢查第 5 個欄位 Order method type 的資料錯置情況
sales1.groupby(['Product.2','Order','method','type.1']).size()
# Out:
# Product.2  Order     method     type.1
# Aloe       Relief    E-mail     Australia       3
#                                 Austria         3
#                                 Belgium         3
#                                 Brazil          3
#                                 Canada          3
#                                 China           3
#                                 Denmark         3
#                                 Finland         3
#                                 France          3
#                                 Germany         3
#                                 Italy           3
#                                 Japan           3
#                                 Korea           3
#                                 Mexico          3
#                                 Netherlands     3
#                                 Singapore       3
#                                 Spain           3
#                                 Sweden          3
# ...

# %%
#10.檢查第 6 個欄位 Retailer country 的資料錯置情況
sales1.groupby(['Product.2','Order','method','type.1','Retailer']).size()
# Out:
# Product.2  Order   method  type.1       Retailer
# Aloe       Relief  E-mail  Canada       287.65         1
#                                         2824.2         1
#                                         10792.32       1
#                            France       245.81         1
#                            Germany      481.16         1
#                                         3613.93        1
#                                         10608.95       1
#                            Italy        1746.82        1
#                                         5297.99        1
#                            Japan        1521.93        1
#                                         3823.13        1
#                                         8378.46        1
#                            Korea        3971.59        1
#                            Sweden       2651.61        1
#                            United       Kingdom        3
#                                         States         3
# ...

# %%
#p1 代表的是所有 Product 名稱只占 1 個欄位的紀錄，依此類推
p1 = sales1[sales1['Order'].isin([
        'E-mail', 'Fax', 'Mail', 'Sales', 'Special', 'Telephone', 'Web'
    ])].copy(deep=True)
p2 = sales1[sales1['method'].isin([
        'E-mail', 'Fax', 'Mail', 'Sales', 'Sepcial', 'Telephone', 'Web'
    ])].copy(deep=True)
p3 = sales1[sales1['type.1'].isin([
        'E-mail', 'Fax', 'Mail', 'Sales', 'Speical', 'Telephone', 'Web'
    ])].copy(deep=True)
p4 = sales1[sales1['Retailer'].isin([
        'E-mail', 'Fax', 'Mail', 'Sales', 'Speical', 'Telephone', 'Web'
    ])].copy(deep=True)
p5 = sales1[sales1['country'].isin([
        'E-mail', 'Fax', 'Mail', 'Sales', 'Speical', 'Telephone', 'Web'
    ])].copy(deep=True)
p6 = sales1[sales1['Revenue'].isin([
        'E-mail', 'Fax', 'Mail', 'Sales', 'Speical', 'Telephone', 'Web'
    ])].copy(deep=True)

# %%
#p1_r1 代表的是所有 Product 名稱只占 1 個欄位且所有Order method type只占1個欄位的紀錄

p1_r1 = p1[p1['method'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain','United'
    ])].copy(deep=True)

p1_r2 = p1[p1['type.1'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain','United'
    ])].copy(deep=True)


p2_r1 = p2[p2['type.1'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain','United'
    ])].copy(deep=True)

p2_r2 = p2[p2['Retailer'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain','United'
    ])].copy(deep=True)

p3_r1 = p3[p3['Retailer'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain','United'
    ])].copy(deep=True)

p3_r2 = p3[p3['country'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain','United'
    ])].copy(deep=True)

p4_r1 = p4[p4['country'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain','United'
    ])].copy(deep=True)

p4_r2 = p4[p4['Revenue'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain','United'
    ])].copy(deep=True)

p5_r1 = p5[p5['Revenue'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain','United'
    ])].copy(deep=True)
p5_r2 = p5[p5['Planned'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain','United'
    ])].copy(deep=True)


p6_r1 = p6[p6['Planned'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain','United'
    ])].copy(deep=True)

p6_r2 = p6[p6['revenue'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain','United'
    ])].copy(deep=True)

# %%
"""
p1_r1_c1代表的是所有 Product 名稱只占 1 個欄位且所有Order method type只占1個欄位
且Retailer country只占1個欄位的紀錄

"""


p1_r1_c1= p1_r1[p1_r1['method'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain'
    ])].copy(deep=True)

p1_r1_c2= p1_r1[p1_r1['type.1'].isin([
        'Kingdom','States'
    ])].copy(deep=True)

p1_r2_c1= p1_r2[p1_r2['type.1'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain'
    ])].copy(deep=True)

p1_r2_c2= p1_r2[p1_r2['Retailer'].isin([
        'Kingdom','States'
    ])].copy(deep=True)



p2_r1_c1= p2_r1[p2_r1['type.1'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain'
    ])].copy(deep=True)

p2_r1_c2= p2_r1[p2_r1['Retailer'].isin([
        'Kingdom','States'
    ])].copy(deep=True)

p2_r2_c1= p2_r2[p2_r2['Retailer'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain'
    ])].copy(deep=True)

p2_r2_c2= p2_r2[p2_r2['country'].isin([
        'Kingdom','States'
    ])].copy(deep=True)




p3_r1_c1= p3_r1[p3_r1['Retailer'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain'
    ])].copy(deep=True)

p3_r1_c2= p3_r1[p3_r1['country'].isin([
        'Kingdom','States'
    ])].copy(deep=True)

p3_r2_c1= p3_r2[p3_r2['country'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain'
    ])].copy(deep=True)

p3_r2_c2= p3_r2[p3_r2['Revenue'].isin([
        'Kingdom','States'
    ])].copy(deep=True)


p4_r1_c1= p4_r1[p4_r1['country'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain'
    ])].copy(deep=True)

p4_r1_c2= p4_r1[p4_r1['Revenue'].isin([
        'Kingdom','States'
    ])].copy(deep=True)

p4_r2_c1= p4_r2[p4_r2['Revenue'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain'
    ])].copy(deep=True)

p4_r2_c2= p4_r2[p4_r2['Planned'].isin([
        'Kingdom','States'
    ])].copy(deep=True)



p5_r1_c1= p5_r1[p5_r1['Revenue'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain'
    ])].copy(deep=True)

p5_r1_c2= p5_r1[p5_r1['Planned'].isin([
        'Kingdom','States'
    ])].copy(deep=True)

p5_r2_c1= p5_r2[p5_r2['Planned'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain'
    ])].copy(deep=True)

p5_r2_c2= p5_r2[p5_r2['revenue'].isin([
        'Kingdom','States'
    ])].copy(deep=True)




p6_r1_c1= p6_r1[p6_r1['Planned'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain'
    ])].copy(deep=True)

p6_r1_c2= p6_r1[p6_r1['revenue'].isin([
        'Kingdom','States'
    ])].copy(deep=True)

p6_r2_c1= p6_r2[p6_r2['revenue'].isin([
        'Canada', 'Mexico', 'Brazil', 'Japan', 'Korea', 'China',\
        'Singapore','Australia','Netherlands','Sweden','Finland',\
        'Denmark','France','Germany','Belgium','Switzerland','Austria'\
        'Finland','Italy','Spain'
    ])].copy(deep=True)

p6_r2_c2= p6_r2[p6_r2['Product.3'].isin([
        'Kingdom','States'
    ])].copy(deep=True)

# %%
#11. 將剩下的欄位整理成正確的形式(Revenue、Planned、Product cost、Unit cost、Unit price、Gross profit、Unit sale price)

p1_r1_c1['Revenue.new']=p1_r1_c1['type.1']
p1_r1_c1['Planned revenue']=p1_r1_c1['Retailer']
p1_r1_c1['Product.3 cost']=p1_r1_c1['country']
p1_r1_c1['Quantity.new']=p1_r1_c1['Revenue']
p1_r1_c1['Unit cost.1']=p1_r1_c1['Planned']
p1_r1_c1['Unit.1 price']=p1_r1_c1['revenue']
p1_r1_c1['Gross profit']=p1_r1_c1['Product.3']
p1_r1_c1['Unit.2 sale price.1']=p1_r1_c1['cost']

p1_r1_c2['Revenue.new']=p1_r1_c2['Retailer']
p1_r1_c2['Planned revenue']=p1_r1_c2['country']
p1_r1_c2['Product.3 cost']=p1_r1_c2['Revenue']
p1_r1_c2['Quantity.new']=p1_r1_c2['Planned']
p1_r1_c2['Unit cost.1']=p1_r1_c2['revenue']
p1_r1_c2['Unit.1 price']=p1_r1_c2['Product.3']
p1_r1_c2['Gross profit']=p1_r1_c2['cost']
p1_r1_c2['Unit.2 sale price.1']=p1_r1_c2['Quantity']

p1_r2_c1['Revenue.new']=p1_r2_c1['Retailer']
p1_r2_c1['Planned revenue']=p1_r2_c1['country']
p1_r2_c1['Product.3 cost']=p1_r2_c1['Revenue']
p1_r2_c1['Quantity.new']=p1_r2_c1['Planned']
p1_r2_c1['Unit cost.1']=p1_r2_c1['revenue']
p1_r2_c1['Unit.1 price']=p1_r2_c1['Product.3']
p1_r2_c1['Gross profit']=p1_r2_c1['cost']
p1_r2_c1['Unit.2 sale price.1']=p1_r2_c1['Quantity']

p1_r2_c2['Revenue.new']=p1_r2_c2['country']
p1_r2_c2['Planned revenue']=p1_r2_c2['Revenue']
p1_r2_c2['Product.3 cost']=p1_r2_c2['Planned']
p1_r2_c2['Quantity.new']=p1_r2_c2['revenue']
p1_r2_c2['Unit cost.1']=p1_r2_c2['Product.3']
p1_r2_c2['Unit.1 price']=p1_r2_c2['cost']
p1_r2_c2['Gross profit']=p1_r2_c2['Quantity']
p1_r2_c2['Unit.2 sale price.1']=p1_r2_c2['Unit']

# %%
#11. 將剩下的欄位整理成正確的形式(Revenue、Planned、Product cost、Unit cost、Unit price、Gross profit、Unit sale price)


p2_r1_c1['Revenue.new']=p2_r1_c1['Retailer']
p2_r1_c1['Planned revenue']=p2_r1_c1['country']
p2_r1_c1['Product.3 cost']=p2_r1_c1['Revenue']
p2_r1_c1['Quantity.new']=p2_r1_c1['Planned']
p2_r1_c1['Unit cost.1']=p2_r1_c1['revenue']
p2_r1_c1['Unit.1 price']=p2_r1_c1['Product.3']
p2_r1_c1['Gross profit']=p2_r1_c1['cost']
p2_r1_c1['Unit.2 sale price.1']=p2_r1_c1['Quantity']

p2_r1_c2['Revenue.new']=p2_r1_c2['country']
p2_r1_c2['Planned revenue']=p2_r1_c2['Revenue']
p2_r1_c2['Product.3 cost']=p2_r1_c2['Planned']
p2_r1_c2['Quantity.new']=p2_r1_c2['revenue']
p2_r1_c2['Unit cost.1']=p2_r1_c2['Product.3']
p2_r1_c2['Unit.1 price']=p2_r1_c2['cost']
p2_r1_c2['Gross profit']=p2_r1_c2['Quantity']
p2_r1_c2['Unit.2 sale price.1']=p2_r1_c2['Unit']

p2_r2_c1['Revenue.new']=p2_r2_c1['country']
p2_r2_c1['Planned revenue']=p2_r2_c1['Revenue']
p2_r2_c1['Product.3 cost']=p2_r2_c1['Planned']
p2_r2_c1['Quantity.new']=p2_r2_c1['revenue']
p2_r2_c1['Unit cost.1']=p2_r2_c1['Product.3']
p2_r2_c1['Unit.1 price']=p2_r2_c1['cost']
p2_r2_c1['Gross profit']=p2_r2_c1['Quantity']
p2_r2_c1['Unit.2 sale price.1']=p2_r2_c1['Unit']

p2_r2_c2['Revenue.new']=p2_r2_c2['Revenue']
p2_r2_c2['Planned revenue']=p2_r2_c2['Planned']
p2_r2_c2['Product.3 cost']=p2_r2_c2['revenue']
p2_r2_c2['Quantity.new']=p2_r2_c2['Product.3']
p2_r2_c2['Unit cost.1']=p2_r2_c2['cost']
p2_r2_c2['Unit.1 price']=p2_r2_c2['Quantity']
p2_r2_c2['Gross profit']=p2_r2_c2['Unit']
p2_r2_c2['Unit.2 sale price.1']=p2_r2_c2['cost.1']

# %%
#11. 將剩下的欄位整理成正確的形式(Revenue、Planned、Product cost、Unit cost、Unit price、Gross profit、Unit sale price)


p3_r1_c1['Revenue.new']=p3_r1_c1['country']
p3_r1_c1['Planned revenue']=p3_r1_c1['Revenue']
p3_r1_c1['Product.3 cost']=p3_r1_c1['Planned']
p3_r1_c1['Quantity.new']=p3_r1_c1['revenue']
p3_r1_c1['Unit cost.1']=p3_r1_c1['Product.3']
p3_r1_c1['Unit.1 price']=p3_r1_c1['cost']
p3_r1_c1['Gross profit']=p3_r1_c1['Quantity']
p3_r1_c1['Unit.2 sale price.1']=p2_r1_c1['Unit']

p3_r1_c2['Revenue.new']=p3_r1_c2['Revenue']
p3_r1_c2['Planned revenue']=p3_r1_c2['Planned']
p3_r1_c2['Product.3 cost']=p3_r1_c2['revenue']
p3_r1_c2['Quantity.new']=p3_r1_c2['Product.3']
p3_r1_c2['Unit cost.1']=p3_r1_c2['cost']
p3_r1_c2['Unit.1 price']=p3_r1_c2['Quantity']
p3_r1_c2['Gross profit']=p3_r1_c2['Unit']
p3_r1_c2['Unit.2 sale price.1']=p3_r1_c2['cost.1']

p3_r2_c1['Revenue.new']=p3_r2_c1['Revenue']
p3_r2_c1['Planned revenue']=p3_r2_c1['Planned']
p3_r2_c1['Product.3 cost']=p3_r2_c1['revenue']
p3_r2_c1['Quantity.new']=p3_r2_c1['Product.3']
p3_r2_c1['Unit cost.1']=p3_r2_c1['cost']
p3_r2_c1['Unit.1 price']=p3_r2_c1['Quantity']
p3_r2_c1['Gross profit']=p3_r2_c1['Unit']
p3_r2_c1['Unit.2 sale price.1']=p3_r2_c1['cost.1']

p3_r2_c2['Revenue.new']=p3_r2_c2['Planned']
p3_r2_c2['Planned revenue']=p3_r2_c2['revenue']
p3_r2_c2['Product.3 cost']=p3_r2_c2['Product.3']
p3_r2_c2['Quantity.new']=p3_r2_c2['cost']
p3_r2_c2['Unit cost.1']=p3_r2_c2['Quantity']
p3_r2_c2['Unit.1 price']=p3_r2_c2['Unit']
p3_r2_c2['Gross profit']=p3_r2_c2['cost.1']
p3_r2_c2['Unit.2 sale price.1']=p3_r2_c2['Unit.1']

# %%
#11. 將剩下的欄位整理成正確的形式(Revenue、Planned、Product cost、Unit cost、Unit price、Gross profit、Unit sale price)


p4_r1_c1['Revenue.new']=p4_r1_c1['Revenue']
p4_r1_c1['Planned revenue']=p4_r1_c1['Planned']
p4_r1_c1['Product.3 cost']=p4_r1_c1['revenue']
p4_r1_c1['Quantity.new']=p4_r1_c1['Product.3']
p4_r1_c1['Unit cost.1']=p4_r1_c1['cost']
p4_r1_c1['Unit.1 price']=p4_r1_c1['Quantity']
p4_r1_c1['Gross profit']=p4_r1_c1['Unit']
p4_r1_c1['Unit.2 sale price.1']=p4_r1_c1['cost.1']

p4_r1_c2['Revenue.new']=p4_r1_c2['Planned']
p4_r1_c2['Planned revenue']=p4_r1_c2['revenue']
p4_r1_c2['Product.3 cost']=p4_r1_c2['Product.3']
p4_r1_c2['Quantity.new']=p4_r1_c2['cost']
p4_r1_c2['Unit cost.1']=p4_r1_c2['Quantity']
p4_r1_c2['Unit.1 price']=p4_r1_c2['Unit']
p4_r1_c2['Gross profit']=p4_r1_c2['cost.1']
p4_r1_c2['Unit.2 sale price.1']=p4_r1_c2['Unit.1']

p4_r2_c1['Revenue.new']=p4_r2_c1['Planned']
p4_r2_c1['Planned revenue']=p4_r2_c1['revenue']
p4_r2_c1['Product.3 cost']=p4_r2_c1['Product.3']
p4_r2_c1['Quantity.new']=p4_r2_c1['cost']
p4_r2_c1['Unit cost.1']=p4_r2_c1['Quantity']
p4_r2_c1['Unit.1 price']=p4_r2_c1['Unit']
p4_r2_c1['Gross profit']=p4_r2_c1['cost.1']
p4_r2_c1['Unit.2 sale price.1']=p4_r2_c1['Unit.1']

p4_r2_c2['Revenue.new']=p4_r2_c2['revenue']
p4_r2_c2['Planned revenue']=p4_r2_c2['Product.3']
p4_r2_c2['Product.3 cost']=p4_r2_c2['cost']
p4_r2_c2['Quantity.new']=p4_r2_c2['Quantity']
p4_r2_c2['Unit cost.1']=p4_r2_c2['Unit']
p4_r2_c2['Unit.1 price']=p4_r2_c2['cost.1']
p4_r2_c2['Gross profit']=p4_r2_c2['Unit.1']
p4_r2_c2['Unit.2 sale price.1']=p4_r2_c2['price']

# %%
#11. 將剩下的欄位整理成正確的形式(Revenue、Planned、Product cost、Unit cost、Unit price、Gross profit、Unit sale price)


p5_r1_c1['Revenue.new']=p5_r1_c1['Planned']
p5_r1_c1['Planned revenue']=p5_r1_c1['revenue']
p5_r1_c1['Product.3 cost']=p5_r1_c1['Product.3']
p5_r1_c1['Quantity.new']=p5_r1_c1['cost']
p5_r1_c1['Unit cost.1']=p5_r1_c1['Quantity']
p5_r1_c1['Unit.1 price']=p5_r1_c1['Unit']
p5_r1_c1['Gross profit']=p5_r1_c1['cost.1']
p5_r1_c1['Unit.2 sale price.1']=p5_r1_c1['Unit.1']

p5_r1_c2['Revenue.new']=p5_r1_c2['revenue']
p5_r1_c2['Planned revenue']=p5_r1_c2['Product.3']
p5_r1_c2['Product.3 cost']=p5_r1_c2['cost']
p5_r1_c2['Quantity.new']=p5_r1_c2['Quantity']
p5_r1_c2['Unit cost.1']=p5_r1_c2['Unit']
p5_r1_c2['Unit.1 price']=p5_r1_c2['cost.1']
p5_r1_c2['Gross profit']=p5_r1_c2['Unit.1']
p5_r1_c2['Unit.2 sale price.1']=p5_r1_c2['price']

p5_r2_c1['Revenue.new']=p5_r2_c1['revenue']
p5_r2_c1['Planned revenue']=p5_r2_c1['Product.3']
p5_r2_c1['Product.3 cost']=p5_r2_c1['cost']
p5_r2_c1['Quantity.new']=p5_r2_c1['Quantity']
p5_r2_c1['Unit cost.1']=p5_r2_c1['Unit']
p5_r2_c1['Unit.1 price']=p5_r2_c1['cost.1']
p5_r2_c1['Gross profit']=p5_r2_c1['Unit.1']
p5_r2_c1['Unit.2 sale price.1']=p5_r2_c1['price']

p5_r2_c2['Revenue.new']=p5_r2_c2['Product.3']
p5_r2_c2['Planned revenue']=p5_r2_c2['cost']
p5_r2_c2['Product.3 cost']=p5_r2_c2['Quantity']
p5_r2_c2['Quantity.new']=p5_r2_c2['Unit']
p5_r2_c2['Unit cost.1']=p5_r2_c2['cost.1']
p5_r2_c2['Unit.1 price']=p5_r2_c2['Unit.1']
p5_r2_c2['Gross profit']=p5_r2_c2['price']
p5_r2_c2['Unit.2 sale price.1']=p5_r2_c2['Gross']

# %%
#11. 將剩下的欄位整理成正確的形式(Revenue、Planned、Product cost、Unit cost、Unit price、Gross profit、Unit sale price)


p6_r1_c1['Revenue.new']=p6_r1_c1['revenue']
p6_r1_c1['Planned revenue']=p6_r1_c1['Product.3']
p6_r1_c1['Product.3 cost']=p6_r1_c1['cost']
p6_r1_c1['Quantity.new']=p6_r1_c1['Quantity']
p6_r1_c1['Unit cost.1']=p6_r1_c1['Unit']
p6_r1_c1['Unit.1 price']=p6_r1_c1['cost.1']
p6_r1_c1['Gross profit']=p6_r1_c1['Unit.1']
p6_r1_c1['Unit.2 sale price.1']=p6_r1_c1['price']

p6_r1_c2['Revenue.new']=p6_r1_c2['Product.3']
p6_r1_c2['Planned revenue']=p6_r1_c2['cost']
p6_r1_c2['Product.3 cost']=p6_r1_c2['Quantity']
p6_r1_c2['Quantity.new']=p6_r1_c2['Unit']
p6_r1_c2['Unit cost.1']=p6_r1_c2['cost.1']
p6_r1_c2['Unit.1 price']=p6_r1_c2['Unit.1']
p6_r1_c2['Gross profit']=p6_r1_c2['price']
p6_r1_c2['Unit.2 sale price.1']=p6_r1_c2['Gross']

p6_r2_c1['Revenue.new']=p6_r2_c1['Product.3']
p6_r2_c1['Planned revenue']=p6_r2_c1['cost']
p6_r2_c1['Product.3 cost']=p6_r2_c1['Quantity']
p6_r2_c1['Quantity.new']=p6_r2_c1['Unit']
p6_r2_c1['Unit cost.1']=p6_r2_c1['cost.1']
p6_r2_c1['Unit.1 price']=p6_r2_c1['Unit.1']
p6_r2_c1['Gross profit']=p6_r2_c1['price']
p6_r2_c1['Unit.2 sale price.1']=p6_r2_c1['Gross']

p6_r2_c2['Revenue.new']=p6_r2_c2['cost']
p6_r2_c2['Planned revenue']=p6_r2_c2['Quantity']
p6_r2_c2['Product.3 cost']=p6_r2_c2['Unit']
p6_r2_c2['Quantity.new']=p6_r2_c2['cost.1']
p6_r2_c2['Unit cost.1']=p6_r2_c2['Unit.1']
p6_r2_c2['Unit.1 price']=p6_r2_c2['price']
p6_r2_c2['Gross profit']=p6_r2_c2['Gross']
p6_r2_c2['Unit.2 sale price.1']=p6_r2_c2['profit']

# %%
#10.將第6個欄位Retailer country欄位整理成正確的形式

p1_r1_c1['Retailer country'] = p1_r1_c1['method']
p1_r1_c2['Retailer country'] = p1_r1_c2['method']+' '+p1_r1_c2['type.1']
p1_r2_c1['Retailer country'] = p1_r2_c1['type.1']
p1_r2_c2['Retailer country'] = p1_r2_c2['type.1']+' '+p1_r2_c2['Retailer']


p2_r1_c1['Retailer country'] = p2_r1_c1['type.1']
p2_r1_c2['Retailer country'] = p2_r1_c2['type.1']+' '+p2_r1_c2['Retailer'] 
p2_r2_c1['Retailer country'] = p2_r2_c1['Retailer']
p2_r2_c2['Retailer country'] = p2_r2_c2['Retailer']+' '+p2_r2_c2['country']



p3_r1_c1['Retailer country'] = p3_r1_c1['Retailer']
p3_r1_c2['Retailer country'] = p3_r1_c2['Retailer']+' '+p3_r1_c2['country'] 
p3_r2_c1['Retailer country'] = p3_r2_c1['country']
p3_r2_c2['Retailer country'] = p3_r2_c2['country']+' '+p3_r2_c2['Revenue']



p4_r1_c1['Retailer country'] = p4_r1_c1['country']
p4_r1_c2['Retailer country'] = p4_r1_c2['country']+' '+p4_r1_c2['Revenue'] 
p4_r2_c1['Retailer country'] = p4_r2_c1['Revenue']
p4_r2_c2['Retailer country'] = p4_r2_c2['Revenue']+' '+p4_r2_c2['Planned']


p5_r1_c1['Retailer country'] = p5_r1_c1['Revenue']
p5_r1_c2['Retailer country'] = p5_r1_c2['Revenue']+' '+p5_r1_c2['Planned'] 
p5_r2_c1['Retailer country'] = p5_r2_c1['Planned']
p5_r2_c2['Retailer country'] = p5_r2_c2['Planned']+' '+p5_r2_c2['revenue']


p6_r1_c1['Retailer country'] = p6_r1_c1['Planned']
p6_r1_c2['Retailer country'] = p6_r1_c2['Planned']+' '+p6_r1_c2['revenue'] 
p6_r2_c1['Retailer country'] = p6_r2_c1['revenue']
p6_r2_c2['Retailer country'] = p6_r2_c2['revenue']+' '+p6_r2_c2['Product.3']

# %%
#將p1_r1_c1、p1_r1_c2合併為p1_r1，以此類推

p1_r1 = pd.concat([p1_r1_c1,p1_r1_c2])
p1_r2 = pd.concat([p1_r2_c1,p1_r2_c2])

p2_r1 = pd.concat([p2_r1_c1,p2_r1_c2])
p2_r2 = pd.concat([p2_r2_c1,p2_r2_c2])

p3_r1 = pd.concat([p3_r1_c1,p3_r1_c2])
p3_r2 = pd.concat([p3_r2_c1,p3_r2_c2])

p4_r1 = pd.concat([p4_r1_c1,p4_r1_c2])
p4_r2 = pd.concat([p4_r2_c1,p4_r2_c2])

p5_r1 = pd.concat([p5_r1_c1,p5_r1_c2])
p5_r2 = pd.concat([p5_r2_c1,p5_r2_c2])

p6_r1 = pd.concat([p6_r1_c1,p6_r1_c2])
p6_r2 = pd.concat([p6_r2_c1,p6_r2_c2])

# %%
#9.將第5個欄位Order method type欄位整理成正確的形式。


p1_r1['Order method type.1'] = p1_r1['Order']
p1_r2['Order method type.1'] = p1_r2['Order']+' '+p1_r2['method']

p2_r1['Order method type.1'] = p2_r1['method']
p2_r2['Order method type.1'] = p2_r2['method']+' '+p2_r2['type.1']

p3_r1['Order method type.1'] = p3_r1['type.1']
p3_r2['Order method type.1'] = p3_r2['type.1']+' '+p3_r2['Retailer']

p4_r1['Order method type.1'] = p4_r1['Retailer']
p4_r2['Order method type.1'] = p4_r2['Retailer']+' '+p4_r2['country']

p5_r1['Order method type.1'] = p5_r1['country']
p5_r2['Order method type.1'] = p5_r2['country']+' '+p5_r2['Revenue']

p6_r1['Order method type.1'] = p6_r1['Revenue']
p6_r2['Order method type.1'] = p6_r2['Revenue']+' '+p6_r2['Planned']

# %%
#將p1_r1、p1_r2合併為p1，以此類推

p1= pd.concat([p1_r1,p1_r2])
p2= pd.concat([p2_r1,p2_r2])
p3= pd.concat([p3_r1,p3_r2])
p4= pd.concat([p4_r1,p4_r2])
p5= pd.concat([p5_r1,p5_r2])
p6= pd.concat([p6_r1,p6_r2])

# %%
#8.將第 4 個欄位 Product位整理成正確的形式
#p1第四個欄位Product只佔一欄位，故無需再整理

p2['Product.2']=p2['Product.2']+' '+p2['Order'].astype(str)
p3['Product.2']= p3['Product.2']+' '+p3['Order']+' '+p3['method']
p4['Product.2']= p4['Product.2']+' '+p4['Order']+' '+p4['method']+p4['type.1']
p5['Product.2']= p5['Product.2']+' '+p5['Order']+' '+p5['method'].astype(str)+' '+p5['type.1']+p5['Retailer']
p6['Product.2']= p6['Product.2']+' '+p6['Order']+' '+['method']+p6['type.1']+p6['Retailer']+p6['country']

# %%
#將p1,p2,p3,p4,p5,p6合併
#利用drop()將不需要的欄位移除
#利用reindex()將欄位排序
#12.將整理完的資料集以 index 排序

final= pd.concat([p1,p2,p3,p4,p5,p6],sort=True)
final.drop(['Order','method','type.1','Retailer','country','Planned','revenue','Product.3','cost','Unit','cost.1','Unit.1','price','Gross','profit','Unit.2','sale','price.1'],axis=1)
final = final.reindex(columns=['Year','Product line','Product.1 type','Product.2','Order method type.1', 'Retailer country', 'Revenue.new', 'Planned revenue','Product.3 cost', 'Quantity.new','Unit cost.1', 'Unit.1 price','Gross profit','Unit.2 sale price.1'])

# %%
#利用set_axis()將欄位修正為正確名稱

final.set_axis(['Year','Product line','Product type','Product','Order method type','Retailer country','Revenue','Planned revenue','Product cost','Quantity','Unit cost','Unit price','Gross profit','Unit sale price'],
              axis='columns',inplace = True)

# %%
final
# Out:
#        Year       Product line      Product type                     Product  \
# 2500   2004  Camping Equipment     Sleeping Bags                  Hibernator
# 2501   2004  Camping Equipment     Sleeping Bags                  Hibernator
# 2502   2004  Camping Equipment     Sleeping Bags                  Hibernator
# 2503   2004  Camping Equipment     Sleeping Bags                  Hibernator
# 2504   2004  Camping Equipment     Sleeping Bags                  Hibernator
# 2505   2004  Camping Equipment     Sleeping Bags                  Hibernator
# 2506   2004  Camping Equipment     Sleeping Bags                  Hibernator
# 2507   2004  Camping Equipment     Sleeping Bags                  Hibernator
# 2508   2004  Camping Equipment     Sleeping Bags                  Hibernator
# 2509   2004  Camping Equipment     Sleeping Bags                  Hibernator
# 2510   2004  Camping Equipment     Sleeping Bags                  Hibernator
# ...

# %%
#12.已經將整理完的資料集以 index 排序、將資料匯出成 csv 檔(需保留 index)，檔名為 ECT_HW1_學號.csv
final.to_csv("ECT_HW1_108403201.csv")

# %%
#13. 檢查處理完後的資料集產出如下的結果

final.groupby('Product type').count()
# Out:
#                       Year  Product line  Product  Order method type  \
# Product type
# Climbing Accessories  2520          2520     2520               2520
# Cooking Gear          4800          4800     4800               4800
# First Aid             1800          1800     1800               1800
# Golf Accessories      1440          1440     1440               1440
# Insect Repellents     1800          1800     1800               1800
# Sleeping Bags         2580          2580     2580               2580
#
#                       Retailer country  Revenue  Planned revenue  \
# Product type
# Climbing Accessories              2520      666              666
# Cooking Gear                      4800     1901             1901
# First Aid                         1800      744              744
# Golf Accessories                  1440      574              574
# Insect Repellents                 1800      735              735
# ...
